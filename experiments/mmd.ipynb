# %% [markdown]
# # Ergodic MMD

# %%
# set python to pick up local directory
from pathlib import Path
import sys
import os
path_root = str(Path(os.getcwd()).parents[0])
package_root = str(Path(os.getcwd()).parents[1])
sys.path.append(path_root)
sys.path.append(package_root)

# auto reload
# %reload_ext autoreload
# %autoreload 2

# hush
import warnings
warnings.simplefilter('always', category=FutureWarning)

# %%
import jax 
import jax.numpy as np 
from jax.random import normal
from jax import grad, hessian, vmap, pmap
from jax.flatten_util import ravel_pytree
from jax.lax import scan
from functools import partial
import jax.random as jax_random
import matplotlib.pyplot as plt 
from IPython.display import clear_output

import jaxopt

from emmd.kernel import RBF, create_kernel_matrix
from emmd.target_distributions import Uniform2D, TriModal2D
from emmd.mesh_distributions import BunnyMesh, SphereMesh

import polyscope as ps
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %% [markdown]
# # Unifrom

# %%
x0 =  np.array([0.14,0.15])
xf =  np.array([0.91,0.9])
T = 100
X_init = np.linspace(x0, xf, num=T, endpoint=True)
target_distribution = Uniform2D()
flat_X, unflatten_X = ravel_pytree(X_init)

X_samples = target_distribution.args['x_i']
P_XI      = target_distribution.args['p(x_i)']
h = 0.1
args = {'h' : h, 'X_samples' : X_samples, 'P_XI' : P_XI}
KernelMatrix = create_kernel_matrix(RBF)
def ergodic_mmd(flat_X, args):
    X_init = unflatten_X(flat_X)
    h = args['h']
    X_samples = args['X_samples']
    P_XI = args['P_XI']
    return np.sum(KernelMatrix(X_init, X_init, h))/(T**2) \
            - 2 * np.sum(P_XI @ KernelMatrix(X_init, X_samples, h))/T \
            + np.mean((X_init[1:]-X_init[:-1])**2)

# %%
ergodic_mmd(flat_X, args)
# Out:
# Array(-0.03788818, dtype=float32)

# %%
solver = jaxopt.LBFGSB(fun=ergodic_mmd, maxiter=10_000, tol=1e-4)
bounds = (np.zeros_like(flat_X), np.ones_like(flat_X))
res= solver.run(flat_X, bounds=bounds, args=args)
# Out:
# WARNING: jaxopt.ZoomLineSearch: No interval satisfying curvature condition.Consider increasing maximal possible stepsize of the linesearch.
# WARNING: jaxopt.ZoomLineSearch: Returning stepsize with sufficient decrease but curvature condition not satisfied.
# INFO: jaxopt.ZoomLineSearch: Iter: 1 Minimum Decrease & Curvature Errors (stop. crit.): 0.0001333281397819519 Stepsize:1.0  Decrease Error:0.0  Curvature Error:0.0001333281397819519
# INFO: jaxopt.ZoomLineSearch: Iter: 1 Minimum Decrease & Curvature Errors (stop. crit.): 0.0 Stepsize:1.0  Decrease Error:0.0  Curvature Error:0.0
# INFO: jaxopt.ZoomLineSearch: Iter: 1 Minimum Decrease & Curvature Errors (stop. crit.): 0.0 Stepsize:1.0  Decrease Error:0.0  Curvature Error:0.0
# INFO: jaxopt.ZoomLineSearch: Iter: 1 Minimum Decrease & Curvature Errors (stop. crit.): 0.0 Stepsize:1.0  Decrease Error:0.0  Curvature Error:0.0
# WARNING: jaxopt.ZoomLineSearch: No interval satisfying curvature condition.Consider increasing maximal possible stepsize of the linesearch.
# WARNING: jaxopt.ZoomLineSearch: Returning stepsize with sufficient decrease but curvature condition not satisfied.
# INFO: jaxopt.ZoomLineSearch: Iter: 1 Minimum Decrease & Curvature Errors (stop. crit.): 9.576641605235636e-05 Stepsize:1.0  Decrease Error:0.0  Curvature Error:9.576641605235636e-05
# WARNING: jaxopt.ZoomLineSearch: No interval satisfying curvature condition.Consider increasing maximal possible stepsize of the linesearch.
# WARNING: jaxopt.ZoomLineSearch: Returning stepsize with sufficient decrease but curvature condition not satisfied.
# INFO: jaxopt.ZoomLineSearch: Iter: 1 Minimum Decrease & Curvature Errors (stop. crit.): 0.0004182934353593737 Stepsize:1.0  Decrease Error:0.0  Curvature Error:0.0004182934353593737
# WARNING: jaxopt.ZoomLineSearch: No interval satisfying curvature condition.Consider increasing maximal possible stepsize of the linesearch.
# WARNING: jaxopt.ZoomLineSearch: Returning stepsize with sufficient decrease but curvature condition not satisfied.
# INFO: jaxopt.ZoomLineSearch: Iter: 1 Minimum Decrease & Curvature Errors (stop. crit.): 0.0015146115329116583 Stepsize:1.0  Decrease Error:0.0  Curvature Error:0.0015146115329116583
# WARNING: jaxopt.ZoomLineSearch: No interval satisfying curvature condition.Consider increasing maximal possible stepsize of the linesearch.
# WARNING: jaxopt.ZoomLineSearch: Returning stepsize with sufficient decrease but curvature condition not satisfied.
# INFO: jaxopt.ZoomLineSearch: Iter: 1 Minimum Decrease & Curvature Errors (stop. crit.): 0.004660942126065493 Stepsize:1.0  Decrease Error:0.0  Curvature Error:0.004660942126065493
# WARNING: jaxopt.ZoomLineSearch: No interval satisfying curvature condition.Consider increasing maximal possible stepsize of the linesearch.
# WARNING: jaxopt.ZoomLineSearch: Returning stepsize with sufficient decrease but curvature condition not satisfied.
# INFO: jaxopt.ZoomLineSearch: Iter: 1 Minimum Decrease & Curvature Errors (stop. crit.): 0.007689441554248333 Stepsize:1.0  Decrease Error:0.0  Curvature Error:0.007689441554248333
# INFO: jaxopt.ZoomLineSearch: Iter: 1 Minimum Decrease & Curvature Errors (stop. crit.): 0.0 Stepsize:1.0  Decrease Error:0.0  Curvature Error:0.0
# INFO: jaxopt.ZoomLineSearch: Iter: 1 Minimum Decrease & Curvature Errors (stop. crit.): 0.046626489609479904 Stepsize:1.0  Decrease Error:0.046626489609479904  Curvature Error:0.0
# INFO: jaxopt.ZoomLineSearch: Iter: 2 Minimum Decrease & Curvature Errors (stop. crit.): 0.0 Stepsize:0.4111897051334381  Decrease Error:0.0  Curvature Error:0.0
# INFO: jaxopt.ZoomLineSearch: Iter: 1 Minimum Decrease & Curvature Errors (stop. crit.): 0.0 Stepsize:0.6167845726013184  Decrease Error:0.0  Curvature Error:0.0
# INFO: jaxopt.ZoomLineSearch: Iter: 1 Minimum Decrease & Curvature Errors (stop. crit.): 0.0 Stepsize:0.9251768589019775  Decrease Error:0.0  Curvature Error:0.0
# INFO: jaxopt.ZoomLineSearch: Iter: 1 Minimum Decrease & Curvature Errors (stop. crit.): 0.0 Stepsize:1.0  Decrease Error:0.0  Curvature Error:0.0
# INFO: jaxopt.ZoomLineSearch: Iter: 1 Minimum Decrease & Curvature Errors (stop. crit.): 0.0 Stepsize:1.0  Decrease Error:0.0  Curvature Error:0.0
# INFO: jaxopt.ZoomLineSearch: Iter: 1 Minimum Decrease & Curvature Errors (stop. crit.): 0.0 Stepsize:1.0  Decrease Error:0.0  Curvature Error:0.0
# INFO: jaxopt.ZoomLineSearch: Iter: 1 Minimum Decrease & Curvature Errors (stop. crit.): 0.0 Stepsize:1.0  Decrease Error:0.0  Curvature Error:0.0
# INFO: jaxopt.ZoomLineSearch: Iter: 1 Minimum Decrease & Curvature Errors (stop. crit.): 0.0 Stepsize:1.0  Decrease Error:0.0  Curvature Error:0.0
# INFO: jaxopt.ZoomLineSearch: Iter: 1 Minimum Decrease & Curvature Errors (stop. crit.): 0.0 Stepsize:1.0  Decrease Error:0.0  Curvature Error:0.0
# INFO: jaxopt.ZoomLineSearch: Iter: 1 Minimum Decrease & Curvature Errors (stop. crit.): 0.0 Stepsize:1.0  Decrease Error:0.0  Curvature Error:0.0
# INFO: jaxopt.ZoomLineSearch: Iter: 1 Minimum Decrease & Curvature Errors (stop. crit.): 0.0 Stepsize:1.0  Decrease Error:0.0  Curvature Error:0.0
# INFO: jaxopt.ZoomLineSearch: Iter: 1 Minimum Decrease & Curvature Errors (stop. crit.): 0.0 Stepsize:1.0  Decrease Error:0.0  Curvature Error:0.0
# INFO: jaxopt.ZoomLineSearch: Iter: 1 Minimum Decrease & Curvature Errors (stop. crit.): 0.0 Stepsize:1.0  Decrease Error:0.0  Curvature Error:0.0
# INFO: jaxopt.ZoomLineSearch: Iter: 1 Minimum Decrease & Curvature Errors (stop. crit.): 0.0 Stepsize:1.0  Decrease Error:0.0  Curvature Error:0.0
# INFO: jaxopt.ZoomLineSearch: Iter: 1 Minimum Decrease & Curvature Errors (stop. crit.): 0.0 Stepsize:1.0  Decrease Error:0.0  Curvature Error:0.0
# INFO: jaxopt.ZoomLineSearch: Iter: 1 Minimum Decrease & Curvature Errors (stop. crit.): 0.0 Stepsize:1.0  Decrease Error:0.0  Curvature Error:0.0
# INFO: jaxopt.ZoomLineSearch: Iter: 1 Minimum Decrease & Curvature Errors (stop. crit.): 0.0 Stepsize:1.0  Decrease Error:0.0  Curvature Error:0.0
# INFO: jaxopt.ZoomLineSearch: Iter: 1 Minimum Decrease & Curvature Errors (stop. crit.): 0.0 Stepsize:1.0  Decrease Error:0.0  Curvature Error:0.0
# INFO: jaxopt.ZoomLineSearch: Iter: 1 Minimum Decrease & Curvature Errors (stop. crit.): 7.442577043548226e-06 Stepsize:1.0  Decrease Error:0.0  Curvature Error:7.442577043548226e-06
# INFO: jaxopt.ZoomLineSearch: Iter: 2 Minimum Decrease & Curvature Errors (stop. crit.): 0.0 Stepsize:0.557091236114502  Decrease Error:0.0  Curvature Error:0.0
# INFO: jaxopt.ZoomLineSearch: Iter: 1 Minimum Decrease & Curvature Errors (stop. crit.): 0.0 Stepsize:0.8356368541717529  Decrease Error:0.0  Curvature Error:0.0
# INFO: jaxopt.ZoomLineSearch: Iter: 1 Minimum Decrease & Curvature Errors (stop. crit.): 0.0 Stepsize:1.0  Decrease Error:0.0  Curvature Error:0.0
# INFO: jaxopt.ZoomLineSearch: Iter: 1 Minimum Decrease & Curvature Errors (stop. crit.): 0.0 Stepsize:1.0  Decrease Error:0.0  Curvature Error:0.0
# INFO: jaxopt.ZoomLineSearch: Iter: 1 Minimum Decrease & Curvature Errors (stop. crit.): 9.163541108136997e-07 Stepsize:1.0  Decrease Error:0.0  Curvature Error:9.163541108136997e-07
# INFO: jaxopt.ZoomLineSearch: Iter: 2 Minimum Decrease & Curvature Errors (stop. crit.): 0.0 Stepsize:0.54144287109375  Decrease Error:0.0  Curvature Error:0.0
# INFO: jaxopt.ZoomLineSearch: Iter: 1 Minimum Decrease & Curvature Errors (stop. crit.): 0.0 Stepsize:0.812164306640625  Decrease Error:0.0  Curvature Error:0.0
# INFO: jaxopt.ZoomLineSearch: Iter: 1 Minimum Decrease & Curvature Errors (stop. crit.): 0.0 Stepsize:1.0  Decrease Error:0.0  Curvature Error:0.0
# INFO: jaxopt.ZoomLineSearch: Iter: 1 Minimum Decrease & Curvature Errors (stop. crit.): 0.0 Stepsize:1.0  Decrease Error:0.0  Curvature Error:0.0
# INFO: jaxopt.ZoomLineSearch: Iter: 1 Minimum Decrease & Curvature Errors (stop. crit.): 0.0 Stepsize:1.0  Decrease Error:0.0  Curvature Error:0.0
# INFO: jaxopt.ZoomLineSearch: Iter: 1 Minimum Decrease & Curvature Errors (stop. crit.): 0.0 Stepsize:1.0  Decrease Error:0.0  Curvature Error:0.0
# INFO: jaxopt.ZoomLineSearch: Iter: 1 Minimum Decrease & Curvature Errors (stop. crit.): 0.0 Stepsize:1.0  Decrease Error:0.0  Curvature Error:0.0
# INFO: jaxopt.ZoomLineSearch: Iter: 1 Minimum Decrease & Curvature Errors (stop. crit.): 0.0 Stepsize:1.0  Decrease Error:0.0  Curvature Error:0.0
# INFO: jaxopt.ZoomLineSearch: Iter: 1 Minimum Decrease & Curvature Errors (stop. crit.): 5.916708687436767e-06 Stepsize:1.0  Decrease Error:0.0  Curvature Error:5.916708687436767e-06
# INFO: jaxopt.ZoomLineSearch: Iter: 2 Minimum Decrease & Curvature Errors (stop. crit.): 0.0 Stepsize:0.5404818654060364  Decrease Error:0.0  Curvature Error:0.0
# INFO: jaxopt.ZoomLineSearch: Iter: 1 Minimum Decrease & Curvature Errors (stop. crit.): 0.0 Stepsize:0.810722827911377  Decrease Error:0.0  Curvature Error:0.0

# %%
X_init = unflatten_X(res.params)
plt.plot(X_init[:,0], X_init[:,1], 'r')
# plt.axis('equal')
plt.axis('square')
plt.xlim(0,1)
plt.ylim(0,1)
plt.savefig('uniform_search2D.png')

# %% [markdown]
# # Non Uniform

# %%
x0 =  np.array([0.14,0.15])
xf =  np.array([0.91,0.9])
T = 100
X_init = np.linspace(x0, xf, num=T, endpoint=True)
target_distribution = TriModal2D()
flat_X, unflatten_X = ravel_pytree(X_init)

X_samples = target_distribution.args['x_i']
P_XI      = target_distribution.args['p(x_i)']
h = 0.01
args = {'h' : h, 'X_samples' : X_samples, 'P_XI' : P_XI}
KernelMatrix = create_kernel_matrix(RBF)
def ergodic_mmd(flat_X, args):
    X_init = unflatten_X(flat_X)
    h = args['h']
    X_samples = args['X_samples']
    P_XI = args['P_XI']
    return np.sum(KernelMatrix(X_init, X_init, h))/(T**2) \
            - 2 * np.sum(P_XI @ KernelMatrix(X_init, X_samples, h))/T \
            + np.mean((X_init[1:]-X_init[:-1])**2)
# def ergodic_mmd(flat_X, args):
#     X_init = unflatten_X(flat_X)
#     h = args['h']
#     X_samples = args['X_samples']
#     # P_XI = args['P_XI']
#     P_XI = vmap(target_distribution.p)(X_init)
#     return 4.5*np.sum(KernelMatrix(X_init, X_init, h))/(T**2) \
#             - 2 * np.sum(P_XI)/T \
#             + np.mean((X_init[1:]-X_init[:-1])**2)

# %%
solver = jaxopt.LBFGSB(fun=ergodic_mmd, maxiter=10_000, tol=1e-4)
bounds = (np.zeros_like(flat_X), np.ones_like(flat_X))
res= solver.run(flat_X, bounds=bounds, args=args)
# Out:
# INFO: jaxopt.ZoomLineSearch: Iter: 1 Minimum Decrease & Curvature Errors (stop. crit.): 0.0 Stepsize:1.0  Decrease Error:0.0  Curvature Error:0.0
# INFO: jaxopt.ZoomLineSearch: Iter: 1 Minimum Decrease & Curvature Errors (stop. crit.): 0.0 Stepsize:1.0  Decrease Error:0.0  Curvature Error:0.0
# INFO: jaxopt.ZoomLineSearch: Iter: 1 Minimum Decrease & Curvature Errors (stop. crit.): 0.0 Stepsize:1.0  Decrease Error:0.0  Curvature Error:0.0
# INFO: jaxopt.ZoomLineSearch: Iter: 1 Minimum Decrease & Curvature Errors (stop. crit.): 0.0 Stepsize:1.0  Decrease Error:0.0  Curvature Error:0.0
# WARNING: jaxopt.ZoomLineSearch: No interval satisfying curvature condition.Consider increasing maximal possible stepsize of the linesearch.
# WARNING: jaxopt.ZoomLineSearch: Returning stepsize with sufficient decrease but curvature condition not satisfied.
# INFO: jaxopt.ZoomLineSearch: Iter: 1 Minimum Decrease & Curvature Errors (stop. crit.): 0.000956385862082243 Stepsize:1.0  Decrease Error:0.0  Curvature Error:0
# Out:
# (0.0, 1.0, 0.0, 1.0)

# %%
X_init = unflatten_X(res.params)
target_distribution.plot()
plt.plot(X_init[:,0], X_init[:,1], 'r')

plt.axis('square')
# plt.xlim(0,1)
# plt.ylim(0,1)
# plt.savefig('nonuniform_search2D.png')

# %% [markdown]
# # Animation

# %%
x0 =  np.array([0.14,0.15])
xf =  np.array([0.91,0.9])
T = 100
X_init = np.linspace(x0, xf, num=T, endpoint=True)
target_distribution = Uniform2D()
flat_X, unflatten_X = ravel_pytree(X_init)

bounds = (np.zeros_like(flat_X), np.ones_like(flat_X))

solver = jaxopt.LBFGSB(fun=ergodic_mmd, maxiter=1000)
solver_state = solver.init_state(flat_X, bounds=bounds, args=args)
for _ in range(100): 
    (flat_X, solver_state) = solver.update(params=flat_X, state=solver_state, bounds=bounds, args=args)
    clear_output(wait=True)
    X_init = unflatten_X(flat_X)
    target_distribution.plot()
    plt.plot(X_init[:,0], X_init[:,1], 'r')
    plt.pause(0.001)

# %% [markdown]
# # Search on Mesh

# %%
x0 =  np.array([0.54,0.45, 0.52])
xf =  np.array([0.66,0.535, 0.6])
T = 400
X_init = np.linspace(x0, xf, num=T, endpoint=True)
target_distribution = BunnyMesh()
flat_X, unflatten_X = ravel_pytree(X_init)

X_samples = target_distribution.args['x_i']
P_XI      = target_distribution.args['p(x_i)']
h = 0.1
args = {'h' : h, 'X_samples' : X_samples, 'P_XI' : P_XI}
KernelMatrix = create_kernel_matrix(RBF)
def ergodic_mmd(flat_X, args):
    X_init = unflatten_X(flat_X)
    T = X_init.shape[0]
    h = args['h']
    X_samples = args['X_samples']
    P_XI = args['P_XI']
    return np.sum(KernelMatrix(X_init, X_init, h))/(T**2) \
            - 2 * np.sum(P_XI @ KernelMatrix(X_init, X_samples, h))/T \
            + 0.1*np.mean((X_init[1:]-X_init[:-1])**2)

# %%
solver = jaxopt.LBFGSB(fun=ergodic_mmd, maxiter=10_000, tol=1e-6)
bounds = (np.zeros_like(flat_X), np.ones_like(flat_X))
res= solver.run(flat_X, bounds=bounds, args=args)
X_init = unflatten_X(res.params)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[42], line 3
#       1 solver = jaxopt.LBFGSB(fun=ergodic_mmd, maxiter=10_000, tol=1e-6)
#       2 bounds = (np.zeros_like(flat_X), np.ones_like(flat_X))
# ----> 3 res= solver.run(flat_X, bounds=bounds, args=args)
#       4 X_init = unflatten_X(res.params)
#
# File ~/miniconda3/lib/python3.10/site-packages/jaxopt/_src/base.py:347, in IterativeSolver.run(self, init_params, *args, **kwargs)
#     340   decorator = idf.custom_root(
#     341       self.optimality_fun,
#     342       has_aux=True,
#     343       solve=self.implicit_diff_solve,
#     344       reference_signature=reference_signature)
#     345   run = decorator(run)
# --> 347 return run(init_params, *args, **kwargs)
#
# File ~/miniconda3/lib/python3.10/site-packages/jaxopt/_src/implicit_diff.py:251, in _custom_root.<locals>.wrapped_solver_fun(*args, **kwargs)
#     249 args, kwargs = _signature_bind(solver_fun_signature, *args, **kwargs)
#     250 keys, vals = list(kwargs.keys()), list(kwargs.values())
# --> 251 return make_custom_vjp_solver_fun(solver_fun, keys)(*args, *vals)
#
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/custom_derivatives.py:618, in custom_vjp.__call__(self, *args, **kwargs)
#     615 flat_fwd, out_trees = _flatten_fwd(fwd, self.symbolic_zeros, primal_name,
#     616                                    fwd_name, in_tree, out_type)
#     617 flat_bwd = _flatten_bwd(bwd, in_tree, in_avals, out_trees).call_wrapped
# --> 618 out_flat = custom_vjp_call_p.bind(flat_fun, flat_fwd, flat_bwd,
#     619                                   *args_flat, out_trees=out_trees,
#     620                                   symbolic_zeros=self.symbolic_zeros)
#     621 _, (out_tree, _) = lu.merge_linear_aux(out_type, out_trees)
#     622 return tree_unflatten(out_tree, out_flat)
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/custom_derivatives.py:768, in CustomVJPCallPrimitive.bind(self, fun, fwd, bwd, out_trees, symbolic_zeros, *args)
#     766 tracers = map(top_trace.full_raise, args)  # type: ignore
#     767 bwd_ = lambda *args: bwd(*args)
# --> 768 outs = top_trace.process_custom_vjp_call(self, fun, fwd, bwd_, tracers,
#     769                                          out_trees=out_trees,
#     770                                          symbolic_zeros=symbolic_zeros)
#     771 fst, env_trace_todo = lu.merge_linear_aux(env_trace_todo1, env_trace_todo2)
#     772 if fst:
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/core.py:887, in EvalTrace.process_custom_vjp_call(***failed resolving arguments***)
#     885 del primitive, fwd, bwd, _  # Unused.
#     886 with new_sublevel():
# --> 887   return fun.call_wrapped(*tracers)
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/linear_util.py:191, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     188 gen = gen_static_args = out_store = None
#     190 try:
# --> 191   ans = self.f(*args, **dict(self.params, **kwargs))
#     192 except:
#     193   # Some transformations yield from inside context managers, so we have to
#     194   # interrupt them before reraising the exception. Otherwise they will only
#     195   # get garbage-collected at some later time, running their cleanup tasks
#     196   # only after this exception is handled, which can corrupt the global
#     197   # state.
#     198   while stack:
#
# File ~/miniconda3/lib/python3.10/site-packages/jaxopt/_src/implicit_diff.py:207, in _custom_root.<locals>.make_custom_vjp_solver_fun.<locals>.solver_fun_flat(*flat_args)
#     204 @jax.custom_vjp
#     205 def solver_fun_flat(*flat_args):
#     206   args, kwargs = _extract_kwargs(kwarg_keys, flat_args)
# --> 207   return solver_fun(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.10/site-packages/jaxopt/_src/base.py:314, in IterativeSolver._run(self, init_params, *args, **kwargs)
#     310 init_val = (opt_step, (args, kwargs))
#     312 unroll = self._get_unroll_option()
# --> 314 many_step = loop.while_loop(
#     315     cond_fun=self._cond_fun, body_fun=self._body_fun,
#     316     init_val=init_val, maxiter=self.maxiter - 1, jit=self.jit,
#     317     unroll=unroll)[0]
#     319 return tree_util.tree_map(
#     320     functools.partial(_where, self.maxiter == 0), zero_step, many_step,
#     321     is_leaf=lambda x: x is None)
#
# File ~/miniconda3/lib/python3.10/site-packages/jaxopt/_src/loop.py:82, in while_loop(cond_fun, body_fun, init_val, maxiter, unroll, jit)
#      77 if jit and fun is not _while_loop_lax:
#      78   # jit of a lax while_loop is redundant, and this jit would only
#      79   # constrain maxiter to be static where it is not required.
#      80   fun = jax.jit(fun, static_argnums=(0, 1, 3))
# ---> 82 return fun(cond_fun, body_fun, init_val, maxiter)
#
# File ~/miniconda3/lib/python3.10/site-packages/jaxopt/_src/loop.py:60, in _while_loop_lax(cond_fun, body_fun, init_val, maxiter)
#      57   val = body_fun(val)
#      58   return it+1, val
# ---> 60 return jax.lax.while_loop(_cond_fun, _body_fun, (0, init_val))[1]
#
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/lax/control_flow/loops.py:1243, in while_loop(cond_fun, body_fun, init_val)
#    1240 if disallowed_effects:
#    1241   raise NotImplementedError(
#    1242       f'Effects not supported in `while`: {disallowed_effects}')
# -> 1243 outs = while_p.bind(*cond_consts, *body_consts, *init_vals,
#    1244                     cond_nconsts=len(cond_consts), cond_jaxpr=cond_jaxpr,
#    1245                     body_nconsts=len(body_consts), body_jaxpr=body_jaxpr)
#    1246 return tree_unflatten(body_tree, outs)
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/core.py:2656, in AxisPrimitive.bind(self, *args, **params)
#    2652 axis_main = max((axis_frame(a).main_trace for a in used_axis_names(self, params)),
#    2653                 default=None, key=lambda t: getattr(t, 'level', -1))
#    2654 top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2655              else axis_main.with_cur_sublevel())
# -> 2656 return self.bind_with_trace(top_trace, args, params)
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/core.py:388, in Primitive.bind_with_trace(self, trace, args, params)
#     387 def bind_with_trace(self, trace, args, params):
# --> 388   out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     389   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/core.py:868, in EvalTrace.process_primitive(self, primitive, tracers, params)
#     867 def process_primitive(self, primitive, tracers, params):
# --> 868   return primitive.impl(*tracers, **params)
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/dispatch.py:140, in apply_primitive(prim, *args, **params)
#     136   msg = pjit._device_assignment_mismatch_error(
#     137       prim.name, fails, args, 'jit', arg_names)
#     138   raise ValueError(msg) from None
# --> 140 return compiled_fun(*args)
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/profiler.py:340, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     337 @wraps(func)
#     338 def wrapper(*args, **kwargs):
#     339   with TraceAnnotation(name, **decorator_kwargs):
# --> 340     return func(*args, **kwargs)
#     341   return wrapper
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/interpreters/pxla.py:1144, in ExecuteReplicated.__call__(self, *args)
#    1141 if (self.ordered_effects or self.has_unordered_effects
#    1142     or self.has_host_callbacks):
#    1143   input_bufs = self._add_tokens_to_inputs(input_bufs)
# -> 1144   results = self.xla_executable.execute_sharded(
#    1145       input_bufs, with_tokens=True
#    1146   )
#    1147   result_token_bufs = results.disassemble_prefix_into_single_device_arrays(
#    1148       len(self.ordered_effects))
#    1149   sharded_runtime_token = results.consume_token()
#
# KeyboardInterrupt:

# %%
# Visualize
ps.init()
ps_cloud = ps.register_point_cloud("my cloud", target_distribution.args['x_i'])
traj_cloud = ps.register_point_cloud("traj cloud", X_init)

# for i in range(n_eig):
    # ps_cloud.add_scalar_quantity("eigenvector_"+str(i), evecs[:,i], enabled=True)
ps.show()
# fig = plt.figure()
# ax = fig.add_subplot(projection='3d')
# X_init = unflatten_X(res.params)

# ax.scatter(X_init[:,0], X_init[:,1], X_init[:,2])
# Out:
# [polyscope] Backend: openGL3_glfw -- Loaded openGL version: 4.1 Metal - 88

# %% [markdown]
# # Animation

# %%
x0 =  np.array([0.54,0.45, 0.52])
xf =  np.array([0.66,0.535, 0.6])
T = 400
X_init = np.linspace(x0, xf, num=T, endpoint=True)
target_distribution = BunnyMesh()
flat_X, unflatten_X = ravel_pytree(X_init)

bounds = (np.zeros_like(flat_X), np.ones_like(flat_X))

solver = jaxopt.LBFGSB(fun=ergodic_mmd, maxiter=1000)
solver_state = solver.init_state(flat_X, bounds=bounds, args=args)

# ps.set_always_redraw(True)
ps.init()
ps_cloud = ps.register_point_cloud("my cloud", target_distribution.args['x_i'])
traj_cloud = ps.register_point_cloud("traj cloud", X_init)

for _ in range(20000): 
    (flat_X, solver_state) = solver.update(params=flat_X, state=solver_state, bounds=bounds, args=args)
    X_init = unflatten_X(flat_X)
    traj_cloud.update_point_positions(X_init)
    ps.frame_tick()
    # plt.pause(0.001)
# Out:
# [polyscope] Backend: openGL3_glfw -- Loaded openGL version: 4.1 Metal - 88
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 19
#      16 traj_cloud = ps.register_point_cloud("traj cloud", X_init)
#      18 for _ in range(20000):
# ---> 19     (flat_X, solver_state) = solver.update(params=flat_X, state=solver_state, bounds=bounds, args=args)
#      20     X_init = unflatten_X(flat_X)
#      21     traj_cloud.update_point_positions(X_init)
#
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/pjit.py:256, in _cpp_pjit.<locals>.cache_miss(*args, **kwargs)
#     254 @api_boundary
#     255 def cache_miss(*args, **kwargs):
# --> 256   outs, out_flat, out_tree, args_flat, jaxpr = _python_pjit_helper(
#     257       fun, infer_params_fn, *args, **kwargs)
#     258   executable = _read_most_recent_pjit_call_executable(jaxpr)
#     259   fastpath_data = _get_fastpath_data(executable, out_tree, args_flat, out_flat)
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/pjit.py:167, in _python_pjit_helper(fun, infer_params_fn, *args, **kwargs)
#     165   dispatch.check_arg(arg)
#     166 try:
# --> 167   out_flat = pjit_p.bind(*args_flat, **params)
#     168 except pxla.DeviceAssignmentMismatchError as e:
#     169   fails, = e.args
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/core.py:2656, in AxisPrimitive.bind(self, *args, **params)
#    2652 axis_main = max((axis_frame(a).main_trace for a in used_axis_names(self, params)),
#    2653                 default=None, key=lambda t: getattr(t, 'level', -1))
#    2654 top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2655              else axis_main.with_cur_sublevel())
# -> 2656 return self.bind_with_trace(top_trace, args, params)
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/core.py:388, in Primitive.bind_with_trace(self, trace, args, params)
#     387 def bind_with_trace(self, trace, args, params):
# --> 388   out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     389   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/core.py:868, in EvalTrace.process_primitive(self, primitive, tracers, params)
#     867 def process_primitive(self, primitive, tracers, params):
# --> 868   return primitive.impl(*tracers, **params)
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/pjit.py:1212, in _pjit_call_impl(jaxpr, in_shardings, out_shardings, resource_env, donated_invars, name, keep_unused, inline, *args)
#    1209 donated_argnums = [i for i, d in enumerate(donated_invars) if d]
#    1210 has_explicit_sharding = _pjit_explicit_sharding(
#    1211     in_shardings, out_shardings, None, None)
# -> 1212 return xc._xla.pjit(name, f, call_impl_cache_miss, [], [], donated_argnums,
#    1213                     tree_util.dispatch_registry,
#    1214                     _get_cpp_global_cache(has_explicit_sharding))(*args)
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/pjit.py:1196, in _pjit_call_impl.<locals>.call_impl_cache_miss(*args_, **kwargs_)
#    1195 def call_impl_cache_miss(*args_, **kwargs_):
# -> 1196   out_flat, compiled = _pjit_call_impl_python(
#    1197       *args, jaxpr=jaxpr, in_shardings=in_shardings,
#    1198       out_shardings=out_shardings, resource_env=resource_env,
#    1199       donated_invars=donated_invars, name=name, keep_unused=keep_unused,
#    1200       inline=inline)
#    1201   fastpath_data = _get_fastpath_data(
#    1202       compiled, tree_structure(out_flat), args, out_flat)
#    1203   return out_flat, fastpath_data
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/pjit.py:1152, in _pjit_call_impl_python(jaxpr, in_shardings, out_shardings, resource_env, donated_invars, name, keep_unused, inline, *args)
#    1146   distributed_debug_log(("Running pjit'd function", name),
#    1147                         ("in_shardings", in_shardings),
#    1148                         ("out_shardings", out_shardings),
#    1149                         ("abstract args", map(xla.abstractify, args)),
#    1150                         ("fingerprint", fingerprint))
#    1151 try:
# -> 1152   return compiled.unsafe_call(*args), compiled
#    1153 except FloatingPointError:
#    1154   assert config.debug_nans.value or config.debug_infs.value  # compiled_fun can only raise in this case
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/profiler.py:340, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     337 @wraps(func)
#     338 def wrapper(*args, **kwargs):
#     339   with TraceAnnotation(name, **decorator_kwargs):
# --> 340     return func(*args, **kwargs)
#     341   return wrapper
#
# File ~/miniconda3/lib/python3.10/site-packages/jax/_src/interpreters/pxla.py:1144, in ExecuteReplicated.__call__(self, *args)
#    1141 if (self.ordered_effects or self.has_unordered_effects
#    1142     or self.has_host_callbacks):
#    1143   input_bufs = self._add_tokens_to_inputs(input_bufs)
# -> 1144   results = self.xla_executable.execute_sharded(
#    1145       input_bufs, with_tokens=True
#    1146   )
#    1147   result_token_bufs = results.disassemble_prefix_into_single_device_arrays(
#    1148       len(self.ordered_effects))
#    1149   sharded_runtime_token = results.consume_token()
#
# KeyboardInterrupt:
